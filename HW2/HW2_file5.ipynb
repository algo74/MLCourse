# %% [markdown]
# <a href="https://colab.research.google.com/github/algo74/MLCourse/blob/master/HW2/HW2_file5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW2. Data augmentation

# %% [markdown]
# * Dropouts helped to raise accuracy to ~80%.
# * To combat overfitting further, let's try image augmentation.

# %% [markdown]
# ## Credits
# * Data loading is based on cifar10_data_set.ipynb
# * Several ideas were borrowed from https://adventuresinmachinelearning.com/keras-tutorial-cnn-11-lines/
# * Several ideas were borrowed from https://arxiv.org/pdf/1409.1556.pdf
# * Dropouts parameters are borrowed from https://github.com/keras-team/keras/blob/master/examples/cifar10_cnn.py
# * Data augmentation from https://github.com/BIGBALLON/cifar-10-cnn/blob/master/3_Vgg19_Network/Vgg19_keras.py

# %% [markdown]
# ## Loading the CIFAR10 data set

# %%
from keras.datasets import cifar10

(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preparing the data

# %%
from keras.utils import to_categorical

orig_tr_y = to_categorical(train_labels)

test_y = to_categorical(test_labels)

orig_tr_x = train_images.astype('float32') / 255

test_x = test_images.astype('float32') / 255 

class_names = ['airplan', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## Splitting original train set into smaller train and validate sets

# %%
import numpy as np
# we want to split "randomly" but reproducible
np.random.seed(1000)
m=len(orig_tr_x)
m_tr = int(m * 0.9) # will split 90:10
m_val = m - m_tr
shuffled_indices = np.random.permutation(m)
orig_tr_x_s = orig_tr_x[shuffled_indices]
orig_tr_y_s = orig_tr_y[shuffled_indices]
# splitting
tr_x = orig_tr_x_s[:m_tr]
tr_y = orig_tr_y_s[:m_tr]
val_x = orig_tr_x_s[m_tr:]
val_y = orig_tr_y_s[m_tr:]
#print(len(tr_x), m_tr)
#print(len(val_x), m_val)

# %% [markdown]
# ## Setting up Keras and general structure of networks

# %% [markdown]
# ### A few things to beautify outputs

# %%
from IPython.display import HTML, display
from keras.callbacks import Callback
import matplotlib.pyplot as plt
import time

def plot_fit_history(history):
  tr_acc = history['acc']
  val_acc = history['val_acc']
  tr_loss = history['loss']
  val_loss = history['val_loss']
  epochs_range = range(1, len(tr_acc) + 1)
  fig, ax1 = plt.subplots()

  color = 'tab:red'
  ax1.set_xlabel('Epochs')
  ax1.set_ylabel('Loss', color=color)
  l1, = ax1.plot(epochs_range, tr_loss, 's:', color=color, label='Training Loss', markeredgewidth=1, fillstyle='none')
  l2, = ax1.plot(epochs_range, val_loss, 'o-', color=color, label='Validation Loss')
  ax1.tick_params(axis='y', labelcolor=color, grid_color=color, grid_linestyle=':')

  ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

  color = 'tab:blue'
  ax2.set_ylabel('Accuracy', color=color)  # we already handled the x-label with ax1
  l3, = ax2.plot(epochs_range, tr_acc, 's:', color=color, label='Training Acc', markeredgewidth=1, fillstyle='none')
  l4, = ax2.plot(epochs_range, val_acc, 'o-', color=color, label='Validation Acc')
  ax2.tick_params(axis='y', labelcolor=color, grid_color=color, grid_linestyle=':')

  fig.tight_layout()  # otherwise the right y-label is slightly clipped
  
#   plt.plot(epochs_range, tr_acc, 'bo--', label='Training Acc')
#   plt.plot(epochs_range, val_acc, 'ro--', label='Validation Acc')
  
  plt.legend((l1, l2, l3, l4), ('Training Loss', 'Validation Loss', 'Training Acc', 'Validation Acc'), loc=(1.2,0.5))
  plt.show()

# https://stackoverflow.com/questions/46939393/how-do-i-use-updatable-displays-on-colab
def progress(hook):
    epoch = hook.ep
    elTime = time.strftime("%H:%M:%S", time.gmtime(time.time() - hook.start_time))
    return HTML("""
        <progress
            value='{epoch}'
            max='{maxEpoch}',
            style='width: 80%'
        >
            {epoch}
        </progress>
        <p>{epoch} of {maxEpoch} epochs complete<br> Time elapsed: {elTime}<br> Training Loss: {trLoss}<br> Training Acc.: {trAcc}<br> Validation Loss: {valLoss}<br> Validation Acc.: {valAcc}</p>
    """.format(epoch=epoch, maxEpoch=hook.params['epochs'], valAcc=hook.val_acc, valLoss=hook.val_loss, trAcc=hook.tr_acc, trLoss=hook.tr_loss, elTime=elTime))
                       
class AccuracyHistory(Callback):
    def __init__(self, epoches=100):
      super().__init__()
      self.epoches = epoches
    def on_train_begin(self, logs={}):
        #print (self.params)
        self.start_time = time.time()
        self.val_acc = 'N/A'
        self.tr_acc = 'N/A'
        self.val_loss = 'N/A'
        self.tr_loss = 'N/A'
        self.ep = 0
        self.pr_bar = display(progress(self), display_id=True)
    def on_epoch_end(self, batch, logs={}):
        self.val_acc = (logs.get('val_acc'))
        self.tr_acc = (logs.get('acc'))
        self.tr_loss = logs.get('loss')
        self.val_loss = logs.get('val_loss')
        self.ep += 1
        self.pr_bar.update(progress(self))

# %% [markdown]
# ### Common network features

# %%
from keras import models, layers

input_shape = tr_x.shape[1:]
print("Input shape:", input_shape)
n_classes = len(class_names)
print("Number of classes:", n_classes)

epochs = 100
batch_size = 128
learnig_rate = 0.1

myHook = AccuracyHistory()

# let's try variable learing rate
sgd = keras.optimizers.SGD(lr=learnig_rate)
change_lr = keras.callbacks.ReduceLROnPlateau(monitor='loss', patience=5, factor=0.3, verbose=1)

cbks = [myHook, change_lr]
# Out:
# Input shape: (32, 32, 3)
# Number of classes: 10

# %% [markdown]
# ### Data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(horizontal_flip=True,
        width_shift_range=0.125,height_shift_range=0.125,fill_mode='constant',cval=0.)

datagen.fit(tr_x)

# %% [markdown]
# ### Training function

# %%
def train(network, ep=epochs, bs = batch_size):
#   history = network.fit(tr_x, 
#                       tr_y, 
#                       epochs=ep, 
#                       batch_size=bs, 
#                       verbose=0,
#                       validation_data=(val_x, val_y),
#                       callbacks=[myHook])
  history = network.fit_generator(datagen.flow(tr_x, tr_y, batch_size=bs),
                    steps_per_epoch=len(tr_x) // bs,
                    epochs=ep,
                    callbacks=cbks,
                    verbose=0,
                    validation_data=(val_x, val_y))
  plot_fit_history(history.history)
  return history

# %% [markdown]
# ## Network 1
# * file 3 network 2 *i.e.* network 4 from file 4

# %%
network = models.Sequential()
network.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape))
network.add(layers.Conv2D(64, (3, 3), activation='relu'))
network.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
network.add(layers.Dropout(0.25))
network.add(layers.Conv2D(128, (3, 3), activation='relu'))
network.add(layers.Conv2D(128, (3, 3), activation='relu'))
network.add(layers.MaxPooling2D(pool_size=(2, 2)))
network.add(layers.Dropout(0.25))
network.add(layers.Flatten())
network.add(layers.Dense(1024, activation='relu'))
network.add(layers.Dropout(0.5))
network.add(layers.Dense(n_classes, activation='softmax'))
network.summary()
network.compile(optimizer=sgd,
                loss='categorical_crossentropy',
                metrics=['accuracy'])
h = train(network)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 30, 30, 64)        1792
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 10, 10, 128)       147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              3277824
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 3,548,234
# Trainable params: 3,548,234
# Non-trainable params: 0
# _________________________________________________________________
#         <progress
#             value='100'
#             max='100',
#             style='width: 80%'
#         >
#             100
#         </progress>
#         <p>100 of 100 epochs complete<br> Time elapsed: 00:38:03<br> Training Loss: 0.4092849447597984<br> Training Acc.: 0.8559235157357071<br> Validation Loss: 0.440209530544281<br> Validation Acc.: 0.8474</p>

# %%
h = train(network)
# Out:
#         <progress
#             value='100'
#             max='100',
#             style='width: 80%'
#         >
#             100
#         </progress>
#         <p>100 of 100 epochs complete<br> Time elapsed: 00:37:56<br> Training Loss: 0.23129077152382096<br> Training Acc.: 0.9180112319061475<br> Validation Loss: 0.39011978681087495<br> Validation Acc.: 0.881</p>
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.030000000447034835.

# %%
h = train(network)
# Out:
#         <progress
#             value='100'
#             max='100',
#             style='width: 80%'
#         >
#             100
#         </progress>
#         <p>100 of 100 epochs complete<br> Time elapsed: 00:37:08<br> Training Loss: 0.19983253363811473<br> Training Acc.: 0.9275049027922234<br> Validation Loss: 0.3846204310417175<br> Validation Acc.: 0.8794</p>
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.009000000357627868.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.002700000163167715.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0008100000210106373.
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00024299999931827186.
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 7.290000066859647e-05.
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 2.18700006371364e-05.
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 6.56100019114092e-06.
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.968300057342276e-06.
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 5.904900035602623e-07.
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.7714700106807868e-07.
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 5.3144100320423605e-08.
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.594322966980144e-08.
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 4.782968687777611e-09.
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.4348906063332833e-09.
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 4.304671952226613e-10.

# %% [markdown]
# After over 200 epoches, the accuracy on the training set reached ~88%. This seems to be the limit for this network.
#
# Probably even more deeper network will produce better results
