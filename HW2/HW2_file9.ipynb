# %% [markdown]
# <a href="https://colab.research.google.com/github/algo74/MLCourse/blob/master/HW2/HW2_file9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW2. Training on the full training set

# %% [markdown]
# * Using full training set to fit the "best network"
# * Validating on the testing set

# %% [markdown]
# ## Preparing saving to files
#
# Needs to be changed if not saving to Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
file_prefix = '/gdrive/My Drive/'
# Out:
# Mounted at /gdrive

# %%
# test saving files
with open(file_prefix + 'foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat "{file_prefix}foo.txt"
# Out:
# Hello Google Drive!

# %% [markdown]
# ## Loading the CIFAR10 data set

# %%
from keras.datasets import cifar10

(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preparing the data

# %%
from keras.utils import to_categorical

orig_tr_y = to_categorical(train_labels)

test_y = to_categorical(test_labels)

orig_tr_x = train_images.astype('float32') / 255

test_x = test_images.astype('float32') / 255 

class_names = ['airplan', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## Setting up Keras and general structure of networks

# %% [markdown]
# ### A few things to beautify outputs

# %%
from IPython.display import HTML, display
from keras.callbacks import Callback
import matplotlib.pyplot as plt
import time

def plot_fit_history(history):
  tr_acc = history['acc']
  val_acc = history['val_acc']
  tr_loss = history['loss']
  val_loss = history['val_loss']
  epochs_range = range(1, len(tr_acc) + 1)
  fig, ax1 = plt.subplots()

  color = 'tab:red'
  ax1.set_xlabel('Epochs')
  ax1.set_ylabel('Loss', color=color)
  l1, = ax1.plot(epochs_range, tr_loss, 's:', color=color, label='Training Loss', markeredgewidth=1, fillstyle='none')
  l2, = ax1.plot(epochs_range, val_loss, 'o-', color=color, label='Validation Loss')
  ax1.tick_params(axis='y', labelcolor=color, grid_color=color, grid_linestyle=':')

  ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

  color = 'tab:blue'
  ax2.set_ylabel('Accuracy', color=color)  # we already handled the x-label with ax1
  l3, = ax2.plot(epochs_range, tr_acc, 's:', color=color, label='Training Acc', markeredgewidth=1, fillstyle='none')
  l4, = ax2.plot(epochs_range, val_acc, 'o-', color=color, label='Validation Acc')
  ax2.tick_params(axis='y', labelcolor=color, grid_color=color, grid_linestyle=':')

  fig.tight_layout()  # otherwise the right y-label is slightly clipped
  
  plt.legend((l1, l2, l3, l4), ('Training Loss', 'Validation Loss', 'Training Acc', 'Validation Acc'), loc=(1.2,0.5))
  plt.show()

# https://stackoverflow.com/questions/46939393/how-do-i-use-updatable-displays-on-colab
def progress(hook):
    epoch = hook.ep
    elTime = time.strftime("%H:%M:%S", time.gmtime(time.time() - hook.start_time))
    return HTML("""
        <progress
            value='{epoch}'
            max='{maxEpoch}',
            style='width: 80%'
        >
            {epoch}
        </progress>
        <p>{epoch} of {maxEpoch} epochs complete<br> Time elapsed: {elTime}<br> Training Loss: {trLoss}<br> Training Acc.: {trAcc}<br> Validation Loss: {valLoss}<br> Validation Acc.: {valAcc}</p>
    """.format(epoch=epoch, maxEpoch=hook.params['epochs'], valAcc=hook.val_acc, valLoss=hook.val_loss, trAcc=hook.tr_acc, trLoss=hook.tr_loss, elTime=elTime))
                       
class AccuracyHistory(Callback):
    def on_train_begin(self, logs={}):
        #print (self.params)
        self.start_time = time.time()
        self.val_acc = 'N/A'
        self.tr_acc = 'N/A'
        self.val_loss = 'N/A'
        self.tr_loss = 'N/A'
        self.ep = 0
        self.pr_bar = display(progress(self), display_id=True)
    def on_epoch_end(self, batch, logs={}):
        self.val_acc = (logs.get('val_acc'))
        self.tr_acc = (logs.get('acc'))
        self.tr_loss = logs.get('loss')
        self.val_loss = logs.get('val_loss')
        self.ep += 1
        self.pr_bar.update(progress(self))

# %% [markdown]
# ### Common network features

# %%
from keras import models, layers
import keras

input_shape = train_images.shape[1:]
print("Input shape:", input_shape)
n_classes = len(class_names)
print("Number of classes:", n_classes)

epochs = 100
batch_size = 128
learnig_rate = 0.1
# Out:
# Input shape: (32, 32, 3)
# Number of classes: 10

# %% [markdown]
# ### Data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(horizontal_flip=True,
                             width_shift_range=0.12,
                             height_shift_range=0.12,
                             zoom_range=0.12,
                             rotation_range=20,
                             fill_mode='nearest')

# %% [markdown]
# ### Training function

# %%
def train(network, tr_x, tr_y, val_x, val_y, ep=epochs, bs = batch_size):
  myHook = AccuracyHistory()
  change_lr = keras.callbacks.ReduceLROnPlateau(monitor='loss', patience=10, factor=0.3, verbose=1, min_lr=0.0001)
  cbks = [myHook, change_lr]
  history = network.fit_generator(datagen.flow(tr_x, tr_y, batch_size=bs),
                    steps_per_epoch=len(tr_x) // bs,
                    epochs=ep,
                    callbacks=cbks,
                    verbose=0,
                    validation_data=(val_x, val_y))
  plot_fit_history(history.history)
  return history

# if network is not a model then restore network from file_name, else use network as is
# after training save network to file_name
def train_and_save(network, file_name, ep=epochs, bs = batch_size):
  
  if not isinstance(network, keras.models.Sequential):
    network = keras.models.load_model(file_name)
    print('Loaded model from ' + file_name)
  
  train(network, orig_tr_x, orig_tr_y, test_x, test_y, ep, bs)
  
  network.save(file_name)
  print('Saved model to ' + file_name)

# %% [markdown]
# ## Network

# %%
def create_network():
  network = models.Sequential()
  network.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape))
  network.add(layers.Conv2D(64, (3, 3), activation='relu'))
  network.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
  network.add(layers.Dropout(0.25))
  network.add(layers.Conv2D(128, (3, 3), activation='relu'))
  network.add(layers.Conv2D(128, (3, 3), activation='relu'))
  network.add(layers.MaxPooling2D(pool_size=(2, 2)))
  network.add(layers.Dropout(0.25))
  network.add(layers.Flatten())
  network.add(layers.Dense(1024, activation='relu'))
  network.add(layers.Dropout(0.5))
  network.add(layers.Dense(n_classes, activation='softmax'))
  network.compile(optimizer=keras.optimizers.SGD(lr=learnig_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
  return network

network = create_network()
network.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 30, 30, 64)        1792
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 10, 10, 128)       147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              3277824
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 3,548,234
# Trainable params: 3,548,234
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
file_name = file_prefix + "file9.h5"

# %%
train_and_save(network, file_name)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#         <progress
#             value='100'
#             max='100',
#             style='width: 80%'
#         >
#             100
#         </progress>
#         <p>100 of 100 epochs complete<br> Time elapsed: 00:46:53<br> Training Loss: 0.4863289393864651<br> Training Acc.: 0.8326315367340391<br> Validation Loss: 0.4356930551528931<br> Validation Acc.: 0.8513</p>
# Saved model to /gdrive/My Drive/file9.h5

# %%
train_and_save(network, file_name)
# Out:
#         <progress
#             value='100'
#             max='100',
#             style='width: 80%'
#         >
#             100
#         </progress>
#         <p>100 of 100 epochs complete<br> Time elapsed: 00:46:45<br> Training Loss: 0.38257902581453856<br> Training Acc.: 0.8659167469102372<br> Validation Loss: 0.4072716912269592<br> Validation Acc.: 0.8726</p>
# Saved model to /gdrive/My Drive/file9.h5

# %%
train_and_save(network, file_name)
# Out:
#         <progress
#             value='100'
#             max='100',
#             style='width: 80%'
#         >
#             100
#         </progress>
#         <p>100 of 100 epochs complete<br> Time elapsed: 00:46:54<br> Training Loss: 0.26464139897929656<br> Training Acc.: 0.9078641321401317<br> Validation Loss: 0.3521453320980072<br> Validation Acc.: 0.8897</p>
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.030000000447034835.
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.009000000357627868.
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 0.002700000163167715.
# Saved model to /gdrive/My Drive/file9.h5

# %%
train_and_save(network, file_name)
# Out:
#         <progress
#             value='100'
#             max='100',
#             style='width: 80%'
#         >
#             100
#         </progress>
#         <p>100 of 100 epochs complete<br> Time elapsed: 00:47:07<br> Training Loss: 0.2611946640180631<br> Training Acc.: 0.908525826153099<br> Validation Loss: 0.3553727111816406<br> Validation Acc.: 0.8894</p>
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0008100000210106373.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.00024299999931827186.
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0001.
# Saved model to /gdrive/My Drive/file9.h5
